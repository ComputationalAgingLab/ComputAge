# %%
import sys
import os
import pandas as pd

import numpy as np
data_library = os.path.abspath('../data_library')
sys.path.append(data_library)
from data_repository import import_data

# %%
from biolearn.data_library import DataLibrary
from base import LinearMethylationModel

# %%
#Example:
# SAMPLE_ID = 'GSE41169_series_matrix.txt'
# URL = 'https://drive.google.com/file/d/1cZca-FHnfeUerXJOzqhnH34mUYjNOgba/view?usp=sharing'
# data_test = import_data(SAMPLE_ID, URL)
# data_test
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1cZca-FHnfeUerXJOzqhnH34mUYjNOgba
# From (redirected): https://drive.google.com/uc?id=1cZca-FHnfeUerXJOzqhnH34mUYjNOgba&confirm=t&uuid=0a94ece2-8b22-46e4-a9a1-f53ae9975c23
# To: /home/ariuna/bioinf_inst/bi_project/ComputAge/computage/deage/GSE41169_series_matrix.txt
# 100%|██████████| 477M/477M [00:06<00:00, 73.2MB/s]
# 0           ID_REF GSM1009660 GSM1009661 GSM1009662 GSM1009663 GSM1009664  \
# 0       cg00000029   0.454931   0.410287   0.375603     0.4872   0.380866
# 1       cg00000108   0.907883   0.915894   0.939018   0.933975   0.939008
# 2       cg00000109   0.862772      0.881   0.889573   0.852267    0.84425
# 3       cg00000165   0.160446     0.1376   0.188573   0.112618   0.119975
# 4       cg00000236    0.72818   0.736708   0.601186   0.659397   0.669548
# ...            ...        ...        ...        ...        ...        ...
# 485573    rs939290   0.507332   0.472005   0.507533   0.974193   0.963453
# 485574    rs951295    0.04052   0.039885   0.040025   0.549087   0.540715
# 485575    rs966367   0.923563   0.032825   0.477915   0.945543    0.44911
# 485576   rs9839873   0.957542   0.946218   0.953063   0.965296   0.952256
# 485577        ages         32         24         65         25         32
#
# 0      GSM1009665 GSM1009666 GSM1009667 GSM1009668  ... GSM1009679 GSM1009680  \
# 0        0.319248   0.364079   0.419343   0.423544  ...   0.428755   0.210384
# 1        0.951529    0.92458   0.915472   0.934989  ...   0.935265   0.924555
# 2        0.863024   0.909848   0.826795   0.910052  ...   0.887857   0.766215
# 3        0.131921   0.108218   0.132647   0.165771  ...    0.15971    0.12041
# 4        0.632081   0.660207    0.69336   0.712032  ...   0.744013   0.671896
# ...           ...        ...        ...        ...  ...        ...        ...
# 485573     0.5348   0.969639   0.494921   0.965082  ...   0.973186   0.963486
# 485574    0.93957   0.532317   0.522733   0.534477  ...   0.534097   0.509521
# 485575   0.492202   0.478855   0.446961   0.443287  ...   0.951256   0.049607
# 485576   0.955124   0.963843   0.545342   0.951037  ...    0.97448    0.85273
# 485577         30         21         21         21  ...         45         32
#
# 0      GSM1009681 GSM1009682 GSM1009683 GSM1009684 GSM1009685 GSM1009686  \
# 0        0.449569    0.40048   0.435775   0.338569   0.396737    0.35699
# 1        0.955041   0.928616   0.937925   0.941029   0.940394   0.937423
# 2        0.880007   0.871054   0.860864   0.880107   0.822451   0.888035
# 3        0.146467   0.132461   0.131419   0.102774   0.121714   0.129066
# 4        0.691565   0.691004   0.685555   0.646149   0.645442   0.721664
# ...           ...        ...        ...        ...        ...        ...
# 485573    0.02004   0.026232   0.022622   0.498687    0.50508   0.973046
# 485574    0.53632   0.955842   0.537719   0.044697   0.963377   0.532193
# 485575   0.952887   0.476839   0.935937   0.460778   0.032539   0.498351
# 485576    0.97253   0.560841   0.041672   0.567387   0.944412   0.966149
# 485577         29         35         30         47         32         36
#
# 0      GSM1009687 GSM1009688
# 0        0.462454    0.42943
# 1         0.93218   0.925551
# 2        0.890643   0.889616
# 3        0.129448   0.155817
# 4        0.674724   0.724572
# ...           ...        ...
# 485573   0.483865   0.966675
# 485574   0.040547   0.036465
# 485575   0.441584   0.467843
# 485576   0.957415   0.949605
# 485577         27         23
#
# [485578 rows x 30 columns]

# %%
#data_test.to_csv('../data_library/data_test.csv', index=False)

# %%
data_test = pd.read_csv('../data_library/data_test.csv')

# %%
data_test_cp = data_test.copy()
data_test_cp
# Out:
#             ID_REF  GSM1009660  GSM1009661  GSM1009662  GSM1009663  \
# 0       cg00000029    0.454931    0.410287    0.375603    0.487200
# 1       cg00000108    0.907883    0.915894    0.939018    0.933975
# 2       cg00000109    0.862772    0.881000    0.889573    0.852267
# 3       cg00000165    0.160446    0.137600    0.188573    0.112618
# 4       cg00000236    0.728180    0.736708    0.601186    0.659397
# ...            ...         ...         ...         ...         ...
# 485573    rs939290    0.507332    0.472005    0.507533    0.974193
# 485574    rs951295    0.040520    0.039885    0.040025    0.549087
# 485575    rs966367    0.923563    0.032825    0.477915    0.945543
# 485576   rs9839873    0.957542    0.946218    0.953063    0.965296
# 485577        ages   32.000000   24.000000   65.000000   25.000000
#
#         GSM1009664  GSM1009665  GSM1009666  GSM1009667  GSM1009668  ...  \
# 0         0.380866    0.319248    0.364079    0.419343    0.423544  ...
# 1         0.939008    0.951529    0.924580    0.915472    0.934989  ...
# 2         0.844250    0.863024    0.909848    0.826795    0.910052  ...
# 3         0.119975    0.131921    0.108218    0.132647    0.165771  ...
# 4         0.669548    0.632081    0.660207    0.693360    0.712032  ...
# ...            ...         ...         ...         ...         ...  ...
# 485573    0.963453    0.534800    0.969639    0.494921    0.965082  ...
# 485574    0.540715    0.939570    0.532317    0.522733    0.534477  ...
# 485575    0.449110    0.492202    0.478855    0.446961    0.443287  ...
# 485576    0.952256    0.955124    0.963843    0.545342    0.951037  ...
# 485577   32.000000   30.000000   21.000000   21.000000   21.000000  ...
#
#         GSM1009679  GSM1009680  GSM1009681  GSM1009682  GSM1009683  \
# 0         0.428755    0.210384    0.449569    0.400480    0.435775
# 1         0.935265    0.924555    0.955041    0.928616    0.937925
# 2         0.887857    0.766215    0.880007    0.871054    0.860864
# 3         0.159710    0.120410    0.146467    0.132461    0.131419
# 4         0.744013    0.671896    0.691565    0.691004    0.685555
# ...            ...         ...         ...         ...         ...
# 485573    0.973186    0.963486    0.020040    0.026232    0.022622
# 485574    0.534097    0.509521    0.536320    0.955842    0.537719
# 485575    0.951256    0.049607    0.952887    0.476839    0.935937
# 485576    0.974480    0.852730    0.972530    0.560841    0.041672
# 485577   45.000000   32.000000   29.000000   35.000000   30.000000
#
#         GSM1009684  GSM1009685  GSM1009686  GSM1009687  GSM1009688
# 0         0.338569    0.396737    0.356990    0.462454    0.429430
# 1         0.941029    0.940394    0.937423    0.932180    0.925551
# 2         0.880107    0.822451    0.888035    0.890643    0.889616
# 3         0.102774    0.121714    0.129066    0.129448    0.155817
# 4         0.646149    0.645442    0.721664    0.674724    0.724572
# ...            ...         ...         ...         ...         ...
# 485573    0.498687    0.505080    0.973046    0.483865    0.966675
# 485574    0.044697    0.963377    0.532193    0.040547    0.036465
# 485575    0.460778    0.032539    0.498351    0.441584    0.467843
# 485576    0.567387    0.944412    0.966149    0.957415    0.949605
# 485577   47.000000   32.000000   36.000000   27.000000   23.000000
#
# [485578 rows x 30 columns]

# %%
X = data_test_cp.iloc[:-1,:]
y = data_test_cp.iloc[-1,:]
y = y.reset_index()
y = pd.DataFrame(y[1:])
y.columns = ['sample','age']
y.reset_index(inplace=True, drop=True)
y
# Out:
#         sample   age
# 0   GSM1009660  32.0
# 1   GSM1009661  24.0
# 2   GSM1009662  65.0
# 3   GSM1009663  25.0
# 4   GSM1009664  32.0
# 5   GSM1009665  30.0
# 6   GSM1009666  21.0
# 7   GSM1009667  21.0
# 8   GSM1009668  21.0
# 9   GSM1009669  24.0
# 10  GSM1009670  24.0
# 11  GSM1009671  34.0
# 12  GSM1009672  36.0
# 13  GSM1009673  65.0
# 14  GSM1009674  49.0
# 15  GSM1009675  20.0
# 16  GSM1009676  29.0
# 17  GSM1009677  33.0
# 18  GSM1009678  24.0
# 19  GSM1009679  45.0
# 20  GSM1009680  32.0
# 21  GSM1009681  29.0
# 22  GSM1009682  35.0
# 23  GSM1009683  30.0
# 24  GSM1009684  47.0
# 25  GSM1009685  32.0
# 26  GSM1009686  36.0
# 27  GSM1009687  27.0
# 28  GSM1009688  23.0

# %%
data_test_cp['ID_REF'].loc[:]
# Out:
# 0         cg00000029
# 1         cg00000108
# 2         cg00000109
# 3         cg00000165
# 4         cg00000236
#              ...
# 485573      rs939290
# 485574      rs951295
# 485575      rs966367
# 485576     rs9839873
# 485577          ages
# Name: ID_REF, Length: 485578, dtype: object

# %%
X.set_index("ID_REF", inplace=True)
X
# Out:
#             GSM1009660  GSM1009661  GSM1009662  GSM1009663  GSM1009664  \
# ID_REF
# cg00000029    0.454931    0.410287    0.375603    0.487200    0.380866
# cg00000108    0.907883    0.915894    0.939018    0.933975    0.939008
# cg00000109    0.862772    0.881000    0.889573    0.852267    0.844250
# cg00000165    0.160446    0.137600    0.188573    0.112618    0.119975
# cg00000236    0.728180    0.736708    0.601186    0.659397    0.669548
# ...                ...         ...         ...         ...         ...
# rs9363764     0.530962    0.945385    0.962389    0.503054    0.509715
# rs939290      0.507332    0.472005    0.507533    0.974193    0.963453
# rs951295      0.040520    0.039885    0.040025    0.549087    0.540715
# rs966367      0.923563    0.032825    0.477915    0.945543    0.449110
# rs9839873     0.957542    0.946218    0.953063    0.965296    0.952256
#
#             GSM1009665  GSM1009666  GSM1009667  GSM1009668  GSM1009669  ...  \
# ID_REF                                                                  ...
# cg00000029    0.319248    0.364079    0.419343    0.423544    0.443042  ...
# cg00000108    0.951529    0.924580    0.915472    0.934989    0.942869  ...
# cg00000109    0.863024    0.909848    0.826795    0.910052    0.892885  ...
# cg00000165    0.131921    0.108218    0.132647    0.165771    0.127599  ...
# cg00000236    0.632081    0.660207    0.693360    0.712032    0.697207  ...
# ...                ...         ...         ...         ...         ...  ...
# rs9363764     0.945157    0.536737    0.044024    0.954359    0.044615  ...
# rs939290      0.534800    0.969639    0.494921    0.965082    0.030082  ...
# rs951295      0.939570    0.532317    0.522733    0.534477    0.534366  ...
# rs966367      0.492202    0.478855    0.446961    0.443287    0.946696  ...
# rs9839873     0.955124    0.963843    0.545342    0.951037    0.046563  ...
#
#             GSM1009679  GSM1009680  GSM1009681  GSM1009682  GSM1009683  \
# ID_REF
# cg00000029    0.428755    0.210384    0.449569    0.400480    0.435775
# cg00000108    0.935265    0.924555    0.955041    0.928616    0.937925
# cg00000109    0.887857    0.766215    0.880007    0.871054    0.860864
# cg00000165    0.159710    0.120410    0.146467    0.132461    0.131419
# cg00000236    0.744013    0.671896    0.691565    0.691004    0.685555
# ...                ...         ...         ...         ...         ...
# rs9363764     0.953008    0.101359    0.479536    0.956382    0.045505
# rs939290      0.973186    0.963486    0.020040    0.026232    0.022622
# rs951295      0.534097    0.509521    0.536320    0.955842    0.537719
# rs966367      0.951256    0.049607    0.952887    0.476839    0.935937
# rs9839873     0.974480    0.852730    0.972530    0.560841    0.041672
#
#             GSM1009684  GSM1009685  GSM1009686  GSM1009687  GSM1009688
# ID_REF
# cg00000029    0.338569    0.396737    0.356990    0.462454    0.429430
# cg00000108    0.941029    0.940394    0.937423    0.932180    0.925551
# cg00000109    0.880107    0.822451    0.888035    0.890643    0.889616
# cg00000165    0.102774    0.121714    0.129066    0.129448    0.155817
# cg00000236    0.646149    0.645442    0.721664    0.674724    0.724572
# ...                ...         ...         ...         ...         ...
# rs9363764     0.944528    0.510115    0.538455    0.513300    0.506395
# rs939290      0.498687    0.505080    0.973046    0.483865    0.966675
# rs951295      0.044697    0.963377    0.532193    0.040547    0.036465
# rs966367      0.460778    0.032539    0.498351    0.441584    0.467843
# rs9839873     0.567387    0.944412    0.966149    0.957415    0.949605
#
# [485577 rows x 29 columns]

# %% [markdown]
# Данные готовы и похожи на биолерновские

# %%
! ls ../models_library/raw_models/
# Out:
# DunedinPoAm.csv			 McCartneyBlood_2018_BMI.csv
# EpiTOC2.csv			 McCartneyBlood_2018_Education.csv
# HannumBlood_2013.csv		 McCartneyBlood_2018_HDL.csv
# HannumBreast_2013.csv		 McCartneyBlood_2018_LDL.csv
# HannumKidney_2013.csv		 McCartneyBlood_2018_Smoking.csv
# HannumLung_2013.csv		 McCartneyBlood_2018_TC.csv
# HorvathMulti_2013.csv		 McCartneyBlood_2018_TotalFat.csv
# HorvathMultiShrunken_2013.csv	 McCartneyBlood_2018_WaistTipRatio.csv
# KnightBlood_2016.csv		 PhenoAge.csv
# LinBlood3CpG_2016.csv		 YingAdaptAge.csv
# LinBlood99CpG_2016.csv		 YingCausAge.csv
# McCartneyBlood_2018_Alcohol.csv  YingDamAge.csv

# %% [markdown]
# Попытка удалить конкретные спгшки, а потмо импутировать их и посмотреть что будет

# %%
from sklearn.model_selection import train_test_split
hovardcsv = pd.read_csv('../models_library/raw_models/HorvathMulti_2013.csv')
hovardcsvfeatures = hovardcsv['Feature_ID']
hovardcsvfeatures_selected, abcc= train_test_split(hovardcsvfeatures, random_state=42, train_size=20)
# что если убрать 20 процентов инфы отсюда, оставить 80. 
hovardcsvfeatures_selected.values
# Out:
# array(['cg27377450', 'cg16984944', 'cg10940099', 'cg19722847',
#        'cg21378206', 'cg19167673', 'cg21801378', 'cg14501253',
#        'cg13216057', 'cg24058132', 'cg03330058', 'cg17853587',
#        'cg27544190', 'cg02489552', 'cg27092035', 'cg09785172',
#        'cg15547534', 'cg13547237', 'cg26723847', 'cg14894144'],
#       dtype=object)

# %%
# from base import LinearMethylationModel
# hovardmodel = LinearMethylationModel('HorvathMulti_2013'.lower())
# hovardmodel.features.values

# %%
list_ofcpgs_todel = hovardcsvfeatures_selected.values
Xcopy =X.copy() 
#Xcopy.drop(list_ofcpgs_todel, inplace=True)

# %%
for i in ['GSM1009660', 'GSM1009661', 'GSM1009662', 'GSM1009663', 'GSM1009664']:
    for j in list_ofcpgs_todel:
        Xcopy.loc[j,i] = np.nan

# %%
Xcopy.loc['cg27377450']
# Out:
# GSM1009660         NaN
# GSM1009661         NaN
# GSM1009662         NaN
# GSM1009663         NaN
# GSM1009664         NaN
# GSM1009665    0.858918
# GSM1009666    0.904331
# GSM1009667    0.818223
# GSM1009668    0.831641
# GSM1009669    0.879590
# GSM1009670    0.808216
# GSM1009671    0.834063
# GSM1009672    0.831365
# GSM1009673    0.838367
# GSM1009674    0.778258
# GSM1009675    0.834371
# GSM1009676    0.873028
# GSM1009677    0.856591
# GSM1009678    0.893150
# GSM1009679    0.853156
# GSM1009680    0.793486
# GSM1009681    0.871719
# GSM1009682    0.844538
# GSM1009683    0.867878
# GSM1009684    0.843622
# GSM1009685    0.854458
# GSM1009686    0.904131
# GSM1009687    0.761478
# GSM1009688    0.835833
# Name: cg27377450, dtype: float64

# %%
means_X = Xcopy.mean(axis=1)
means_X
# Out:
# ID_REF
# cg00000029    0.393776
# cg00000108    0.934271
# cg00000109    0.870661
# cg00000165    0.140918
# cg00000236    0.680249
#                 ...
# rs9363764     0.583498
# rs939290      0.498059
# rs951295      0.499891
# rs966367      0.556332
# rs9839873     0.850196
# Length: 485577, dtype: float64

# %%
X.head()
# Out:
#             GSM1009660  GSM1009661  GSM1009662  GSM1009663  GSM1009664  \
# ID_REF
# cg00000029    0.454931    0.410287    0.375603    0.487200    0.380866
# cg00000108    0.907883    0.915894    0.939018    0.933975    0.939008
# cg00000109    0.862772    0.881000    0.889573    0.852267    0.844250
# cg00000165    0.160446    0.137600    0.188573    0.112618    0.119975
# cg00000236    0.728180    0.736708    0.601186    0.659397    0.669548
#
#             GSM1009665  GSM1009666  GSM1009667  GSM1009668  GSM1009669  ...  \
# ID_REF                                                                  ...
# cg00000029    0.319248    0.364079    0.419343    0.423544    0.443042  ...
# cg00000108    0.951529    0.924580    0.915472    0.934989    0.942869  ...
# cg00000109    0.863024    0.909848    0.826795    0.910052    0.892885  ...
# cg00000165    0.131921    0.108218    0.132647    0.165771    0.127599  ...
# cg00000236    0.632081    0.660207    0.693360    0.712032    0.697207  ...
#
#             GSM1009679  GSM1009680  GSM1009681  GSM1009682  GSM1009683  \
# ID_REF
# cg00000029    0.428755    0.210384    0.449569    0.400480    0.435775
# cg00000108    0.935265    0.924555    0.955041    0.928616    0.937925
# cg00000109    0.887857    0.766215    0.880007    0.871054    0.860864
# cg00000165    0.159710    0.120410    0.146467    0.132461    0.131419
# cg00000236    0.744013    0.671896    0.691565    0.691004    0.685555
#
#             GSM1009684  GSM1009685  GSM1009686  GSM1009687  GSM1009688
# ID_REF
# cg00000029    0.338569    0.396737    0.356990    0.462454    0.429430
# cg00000108    0.941029    0.940394    0.937423    0.932180    0.925551
# cg00000109    0.880107    0.822451    0.888035    0.890643    0.889616
# cg00000165    0.102774    0.121714    0.129066    0.129448    0.155817
# cg00000236    0.646149    0.645442    0.721664    0.674724    0.724572
#
# [5 rows x 29 columns]

# %%
#Xcopy.apply(lambda row: row.fillna(row.mean()), axis=1)
X_filled = Xcopy.where(Xcopy.notna(), Xcopy.mean(axis=1), axis=0)

# %%
X_filled
# Out:
#             GSM1009660  GSM1009661  GSM1009662  GSM1009663  GSM1009664  \
# ID_REF
# cg00000029    0.454931    0.410287    0.375603    0.487200    0.380866
# cg00000108    0.907883    0.915894    0.939018    0.933975    0.939008
# cg00000109    0.862772    0.881000    0.889573    0.852267    0.844250
# cg00000165    0.160446    0.137600    0.188573    0.112618    0.119975
# cg00000236    0.728180    0.736708    0.601186    0.659397    0.669548
# ...                ...         ...         ...         ...         ...
# rs9363764     0.530962    0.945385    0.962389    0.503054    0.509715
# rs939290      0.507332    0.472005    0.507533    0.974193    0.963453
# rs951295      0.040520    0.039885    0.040025    0.549087    0.540715
# rs966367      0.923563    0.032825    0.477915    0.945543    0.449110
# rs9839873     0.957542    0.946218    0.953063    0.965296    0.952256
#
#             GSM1009665  GSM1009666  GSM1009667  GSM1009668  GSM1009669  ...  \
# ID_REF                                                                  ...
# cg00000029    0.319248    0.364079    0.419343    0.423544    0.443042  ...
# cg00000108    0.951529    0.924580    0.915472    0.934989    0.942869  ...
# cg00000109    0.863024    0.909848    0.826795    0.910052    0.892885  ...
# cg00000165    0.131921    0.108218    0.132647    0.165771    0.127599  ...
# cg00000236    0.632081    0.660207    0.693360    0.712032    0.697207  ...
# ...                ...         ...         ...         ...         ...  ...
# rs9363764     0.945157    0.536737    0.044024    0.954359    0.044615  ...
# rs939290      0.534800    0.969639    0.494921    0.965082    0.030082  ...
# rs951295      0.939570    0.532317    0.522733    0.534477    0.534366  ...
# rs966367      0.492202    0.478855    0.446961    0.443287    0.946696  ...
# rs9839873     0.955124    0.963843    0.545342    0.951037    0.046563  ...
#
#             GSM1009679  GSM1009680  GSM1009681  GSM1009682  GSM1009683  \
# ID_REF
# cg00000029    0.428755    0.210384    0.449569    0.400480    0.435775
# cg00000108    0.935265    0.924555    0.955041    0.928616    0.937925
# cg00000109    0.887857    0.766215    0.880007    0.871054    0.860864
# cg00000165    0.159710    0.120410    0.146467    0.132461    0.131419
# cg00000236    0.744013    0.671896    0.691565    0.691004    0.685555
# ...                ...         ...         ...         ...         ...
# rs9363764     0.953008    0.101359    0.479536    0.956382    0.045505
# rs939290      0.973186    0.963486    0.020040    0.026232    0.022622
# rs951295      0.534097    0.509521    0.536320    0.955842    0.537719
# rs966367      0.951256    0.049607    0.952887    0.476839    0.935937
# rs9839873     0.974480    0.852730    0.972530    0.560841    0.041672
#
#             GSM1009684  GSM1009685  GSM1009686  GSM1009687  GSM1009688
# ID_REF
# cg00000029    0.338569    0.396737    0.356990    0.462454    0.429430
# cg00000108    0.941029    0.940394    0.937423    0.932180    0.925551
# cg00000109    0.880107    0.822451    0.888035    0.890643    0.889616
# cg00000165    0.102774    0.121714    0.129066    0.129448    0.155817
# cg00000236    0.646149    0.645442    0.721664    0.674724    0.724572
# ...                ...         ...         ...         ...         ...
# rs9363764     0.944528    0.510115    0.538455    0.513300    0.506395
# rs939290      0.498687    0.505080    0.973046    0.483865    0.966675
# rs951295      0.044697    0.963377    0.532193    0.040547    0.036465
# rs966367      0.460778    0.032539    0.498351    0.441584    0.467843
# rs9839873     0.567387    0.944412    0.966149    0.957415    0.949605
#
# [485577 rows x 29 columns]

# %%
#y.set_index('sample',inplace=True )
#y['age'] = y['actual age']
y# = y[['age']]
#y.re
# Out:
#         sample   age
# 0   GSM1009660  32.0
# 1   GSM1009661  24.0
# 2   GSM1009662  65.0
# 3   GSM1009663  25.0
# 4   GSM1009664  32.0
# 5   GSM1009665  30.0
# 6   GSM1009666  21.0
# 7   GSM1009667  21.0
# 8   GSM1009668  21.0
# 9   GSM1009669  24.0
# 10  GSM1009670  24.0
# 11  GSM1009671  34.0
# 12  GSM1009672  36.0
# 13  GSM1009673  65.0
# 14  GSM1009674  49.0
# 15  GSM1009675  20.0
# 16  GSM1009676  29.0
# 17  GSM1009677  33.0
# 18  GSM1009678  24.0
# 19  GSM1009679  45.0
# 20  GSM1009680  32.0
# 21  GSM1009681  29.0
# 22  GSM1009682  35.0
# 23  GSM1009683  30.0
# 24  GSM1009684  47.0
# 25  GSM1009685  32.0
# 26  GSM1009686  36.0
# 27  GSM1009687  27.0
# 28  GSM1009688  23.0

# %%
#############################################################################
# Visualize the comparison of age predictions
# --------------------------------------------------------------------------

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Prepare data for visualization
comparison_data = pd.DataFrame({
    'Original': original_age_predictions['Predicted'],
    'Imputed': imputed_age_predictions['Predicted']
})

# Create a scatter plot to compare the results
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Original', y='Imputed', data=comparison_data)
plt.title("Comparison of Epigenetic Age Predictions: Original vs Imputed")
plt.xlabel("Original Age Predictions")
plt.ylabel("Imputed Age Predictions")
plt.grid(True)
plt.show()


#############################################################################
# You can also build an imputation decorator to bundle with the clock
# --------------------------------------------------------------------------

from biolearn.model import ImputationDecorator

# Define a custom imputation method using reference averages
def custom_impute_method(dnam_data, needed_cpgs):
    return impute_from_standard(dnam_data, reference_averages, needed_cpgs)

# Wrap the clock model with the imputation decorator
decorated_clock = ImputationDecorator(clock_model, custom_impute_method)

#############################################################################
# You get the same results as running the function directly on your dataset
# --------------------------------------------------------------------------

# Predict epigenetic age using the decorated clock (with imputation)
decorated_clock_predictions = decorated_clock.predict(target_dataset)

# Verify that the results are the same as the direct imputation approach
same_results = all(decorated_clock_predictions == imputed_age_predictions)
print(same_results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3311/1138225274.py in ?()
#       2 target_dataset = X
#       3
#       4 # Perform imputation using the reference averages
#       5 from biolearn.imputation import impute_from_standard
# ----> 6 imputed_data = impute_from_standard(target_dataset.dnam, reference_averages)
#       7 imputed_dataset = GeoData(target_dataset.metadata, imputed_data)
#       8
#       9 #############################################################################
#
# ~/.local/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dnam'

# %% [markdown]
# 1) разбить на треин и тест
# 2) применить модель из биолерна с выбором импутации
# 3) проверить MAE из ск.леарна
