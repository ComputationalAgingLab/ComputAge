# %% [markdown]
# ### Скачивание с облака заданного датасета

# %%
import os
import sys

utils_dir = os.path.abspath('../utils')
sys.path.append(utils_dir)
from data_utils import download_meta, download_dataset

# %%
# meta = download_meta('./meta_table_datasets.xlsx')
# download_dataset(meta, 'GSE132203', '.')
# Out:
# Dataset GSE132203 saved to .

# %%
import pandas as pd
import gzip

# with gzip.open('GSE132203.pkl.gz','rb')as f_in:
#     with open('GSE132203.pkl', 'wb') as f_out:
#         f_out.write(f_in.read())

df = pd.read_pickle('GSE132203.pkl')

# %% [markdown]
# ### Предобработка для использования в biolearn

# %%
data = pd.DataFrame(df['data'])
data = data.T #For current model
X = data
X
# Out:
#             GSM3853125  GSM3853126  GSM3853127  GSM3853128  GSM3853129  \
# cg00000029    0.592053    0.542467    0.466598    0.582700    0.586890
# cg00000103    0.987501    0.936105    0.982851    0.962205    0.986249
# cg00000109    0.983161    0.986668    0.988104    0.988590    0.967364
# cg00000155    0.985858    0.994086    0.976208    0.983156    0.979459
# cg00000158    0.992408    0.989934    0.989469    0.988471    0.997209
# ...                ...         ...         ...         ...         ...
# rs9363764     0.003187    0.498871    0.007293    0.003511    0.991973
# rs939290      0.003969    0.997551    0.997384    0.595721    0.996531
# rs951295      0.553545    0.574740    0.529805    0.060715    0.546266
# rs966367      0.996854    0.477447    0.984310    0.995005    0.994391
# rs9839873     0.000028    0.684898    0.604418    0.999416    0.999619
#
#             GSM3853130  GSM3853131  GSM3853132  GSM3853133  GSM3853134  ...  \
# cg00000029    0.599623    0.691730    0.545689    0.690579    0.690061  ...
# cg00000103    0.997294    0.992274    0.998444    0.989261    0.970015  ...
# cg00000109    0.982256    0.955827    0.987770    0.974094    0.966388  ...
# cg00000155    0.615387    0.998670    0.984364    0.982757    0.987153  ...
# cg00000158    0.963449    0.998020    0.989225    0.997584    0.983152  ...
# ...                ...         ...         ...         ...         ...  ...
# rs9363764     0.470207    0.000375    0.582829    0.003982    0.002270  ...
# rs939290      0.998495    0.997475    0.998974    0.555213    0.999146  ...
# rs951295      0.953980    0.940583    0.545313    0.542467    0.948355  ...
# rs966367      0.996112    0.518748    0.997164    0.427396    0.458176  ...
# rs9839873     0.998316    0.653039    0.004523    0.638409    0.005433  ...
#
#             GSM3853910  GSM3853911  GSM3853912  GSM3853913  GSM3853914  \
# cg00000029    0.505306    0.466237    0.537291         NaN    0.693709
# cg00000103    1.000000    0.929750    0.943954    0.976402    0.974098
# cg00000109    0.990667    0.951944    0.934649    0.930382    0.953160
# cg00000155    0.972335    0.986494    0.988983    0.980869    0.978321
# cg00000158    0.983456    0.990613    0.989583    0.986383    0.983726
# ...                ...         ...         ...         ...         ...
# rs9363764     0.003341    0.003648    0.003101    0.006281    0.996595
# rs939290      0.983681    0.996873    0.525627    0.984289    0.514717
# rs951295      0.521346    0.508852    0.963340    0.035028    0.952502
# rs966367      0.477011    0.981112    0.995653    0.480051    0.995720
# rs9839873     0.572260    0.006597    0.000976    0.678940    0.603746
#
#             GSM3853915  GSM3853916  GSM3853917  GSM3853918  GSM3853919
# cg00000029    0.551843    0.507195    0.651166    0.479801    0.498205
# cg00000103    0.995657    0.996997    0.997574    0.955905    0.970371
# cg00000109    0.946689    0.973939    0.974010    0.948228    0.996526
# cg00000155    0.970678    0.545064    0.978316    0.973159    0.993636
# cg00000158    0.991711    0.984198    0.985891    0.972671    0.994619
# ...                ...         ...         ...         ...         ...
# rs9363764     0.005252    0.989340    0.001854    0.587137    0.523851
# rs939290      0.978751    0.988657    0.991306    0.988791    0.568975
# rs951295      0.058207    0.945338    0.541269    0.532903    0.956025
# rs966367      0.997415    0.992372    0.994817    0.497377    0.985993
# rs9839873     0.628106    0.662327    0.999235    0.712618    0.672368
#
# [817958 rows x 795 columns]

# %%
from nan_utils import introduce_nans, impute_from_average

# %%
meta = pd.DataFrame(df['meta'])
y = pd.DataFrame(meta['Age'])
y = y.rename(columns={'Age': 'age'})
y
# Out:
#              age
# GSM3853125  49.0
# GSM3853126  21.0
# GSM3853127  44.0
# GSM3853128  51.0
# GSM3853129  52.0
# ...          ...
# GSM3853915  33.0
# GSM3853916  52.0
# GSM3853917  24.0
# GSM3853918  20.0
# GSM3853919  62.0
#
# [795 rows x 1 columns]

# %%
meta_hc = meta[meta['Condition']=='HC']

# %%
meta_hc
# Out:
#                           Title Tissue     CellType Gender   Age Ethnicity  \
# GSM3853125  200928190033_R01C01  Blood  Whole blood      M  49.0        AA
# GSM3853126  200928190033_R02C01  Blood  Whole blood      M  21.0        AA
# GSM3853127  200928190033_R03C01  Blood  Whole blood      M  44.0        AA
# GSM3853128  200928190033_R04C01  Blood  Whole blood      M  51.0        AA
# GSM3853129  200928190033_R05C01  Blood  Whole blood      M  52.0     Other
# ...                         ...    ...          ...    ...   ...       ...
# GSM3853915  201228790041_R02C01  Blood  Whole blood      F  33.0        AA
# GSM3853916  201228790041_R03C01  Blood  Whole blood      F  52.0        AA
# GSM3853917  201228790041_R04C01  Blood  Whole blood      F  24.0        AA
# GSM3853918  201228790041_R05C01  Blood  Whole blood      F  20.0     Other
# GSM3853919  201228790041_R06C01  Blood  Whole blood      F  62.0        AA
#
#            Condition _Merged_caps_and_pss_within_30_days  \
# GSM3853125        HC                                   0
# GSM3853126        HC                                   0
# GSM3853127        HC                                   0
# GSM3853128        HC                                   0
# GSM3853129        HC                                   0
# ...              ...                                 ...
# GSM3853915        HC                                   0
# GSM3853916        HC                                   0
# GSM3853917        HC                                   0
# GSM3853918        HC                                   0
# GSM3853919        HC                                   0
#
#            _tei_total_types_experienced_somewitness  \
# GSM3853125                                       10
# GSM3853126                                        4
# GSM3853127                                        1
# GSM3853128                                        9
# GSM3853129                                     6.33
# ...                                             ...
# GSM3853915                                        4
# GSM3853916                                        3
# GSM3853917                                        4
# GSM3853918                                        4
# GSM3853919                                        3
#
#            _childabphyssexemot_ctq_01modandsev _CD4Tcells(%)  _NKcells(%)  \
# GSM3853125                                   0   0.179390646    0.0576606
# GSM3853126                                   1   0.108943931   0.04749681
# GSM3853127                                   1   0.021528316  0.048931084
# GSM3853128                                   0    0.14558557  0.046814217
# GSM3853129                                   1   0.160881067  0.048052664
# ...                                        ...           ...          ...
# GSM3853915                                   0   0.108429026  0.022446207
# GSM3853916                                   0   0.205673163  0.065169222
# GSM3853917                                   0   0.229676316  0.083885441
# GSM3853918                                   1   0.090158741  0.058399111
# GSM3853919                                   0   0.285580571  0.095984543
#
#              _Bcells(%) _Monocytes(%) _Neutrophiles(%)  Platform
# GSM3853125   0.06262448   0.091617955      0.433208068  GPL21145
# GSM3853126  0.043773125    0.17046204      0.599695891  GPL21145
# GSM3853127  0.021704862   0.079550026      0.655035495  GPL21145
# GSM3853128  0.047680269    0.12421703      0.527805456  GPL21145
# GSM3853129   0.05381332   0.071880856      0.595972076  GPL21145
# ...                 ...           ...              ...       ...
# GSM3853915   0.03225725   0.065140096      0.676414449  GPL21145
# GSM3853916  0.059083558   0.110325554      0.351254756  GPL21145
# GSM3853917  0.139712202   0.122082829      0.270495856  GPL21145
# GSM3853918  0.015012963   0.065004855      0.709187029  GPL21145
# GSM3853919   0.09912928   0.094578542      0.267191641  GPL21145
#
# [795 rows x 16 columns]

# %%
meta[meta['Condition']!='HC']
# в этом датасете все здоровые
# Out:
# Empty DataFrame
# Columns: [Title, Tissue, CellType, Gender, Age, Ethnicity, Condition, _Merged_caps_and_pss_within_30_days, _tei_total_types_experienced_somewitness, _childabphyssexemot_ctq_01modandsev, _CD4Tcells(%), _NKcells(%), _Bcells(%), _Monocytes(%), _Neutrophiles(%), Platform]
# Index: []
