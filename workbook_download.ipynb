# %% [markdown]
# ### Скачивание с облака заданного датасета

# %%
import os
import sys

from computage.utils.data_utils import download_meta, download_dataset

# %%
# meta = download_meta('./meta_table_datasets.xlsx')
# download_dataset(meta, 'GSE132203', '.')
# Out:
# Dataset GSE132203 saved to .

# %%
import pandas as pd
import gzip

# with gzip.open('GSE132203.pkl.gz','rb')as f_in:
#     with open('GSE132203.pkl', 'wb') as f_out:
#         f_out.write(f_in.read())

df = pd.read_pickle('GSE132203.pkl')

# %% [markdown]
# ### Предобработка для использования в biolearn

# %%
data = pd.DataFrame(df['data'])
data = data.T #For current model
X = data
X
# Out:
#             GSM3853125  GSM3853126  ...  GSM3853918  GSM3853919
# cg00000029    0.592053    0.542467  ...    0.479801    0.498205
# cg00000103    0.987501    0.936105  ...    0.955905    0.970371
# cg00000109    0.983161    0.986668  ...    0.948228    0.996526
# cg00000155    0.985858    0.994086  ...    0.973159    0.993636
# cg00000158    0.992408    0.989934  ...    0.972671    0.994619
# ...                ...         ...  ...         ...         ...
# rs9363764     0.003187    0.498871  ...    0.587137    0.523851
# rs939290      0.003969    0.997551  ...    0.988791    0.568975
# rs951295      0.553545    0.574740  ...    0.532903    0.956025
# rs966367      0.996854    0.477447  ...    0.497377    0.985993
# rs9839873     0.000028    0.684898  ...    0.712618    0.672368
#
# [817958 rows x 795 columns]

# %%
from computage.utils.nan_utils import introduce_nans, impute_from_average

# %%
meta = pd.DataFrame(df['meta'])
y = pd.DataFrame(meta['Age'])
y = y.rename(columns={'Age': 'age'})
y
# Out:
#              age
# GSM3853125  49.0
# GSM3853126  21.0
# GSM3853127  44.0
# GSM3853128  51.0
# GSM3853129  52.0
# ...          ...
# GSM3853915  33.0
# GSM3853916  52.0
# GSM3853917  24.0
# GSM3853918  20.0
# GSM3853919  62.0
#
# [795 rows x 1 columns]

# %%
meta_hc = meta[meta['Condition']=='HC']

# %%
meta_hc
# Out:
#                           Title Tissue  ... _Neutrophiles(%)  Platform
# GSM3853125  200928190033_R01C01  Blood  ...      0.433208068  GPL21145
# GSM3853126  200928190033_R02C01  Blood  ...      0.599695891  GPL21145
# GSM3853127  200928190033_R03C01  Blood  ...      0.655035495  GPL21145
# GSM3853128  200928190033_R04C01  Blood  ...      0.527805456  GPL21145
# GSM3853129  200928190033_R05C01  Blood  ...      0.595972076  GPL21145
# ...                         ...    ...  ...              ...       ...
# GSM3853915  201228790041_R02C01  Blood  ...      0.676414449  GPL21145
# GSM3853916  201228790041_R03C01  Blood  ...      0.351254756  GPL21145
# GSM3853917  201228790041_R04C01  Blood  ...      0.270495856  GPL21145
# GSM3853918  201228790041_R05C01  Blood  ...      0.709187029  GPL21145
# GSM3853919  201228790041_R06C01  Blood  ...      0.267191641  GPL21145
#
# [795 rows x 16 columns]

# %%
meta[meta['Condition']!='HC']
# в этом датасете все здоровые
# Out:
# Empty DataFrame
# Columns: [Title, Tissue, CellType, Gender, Age, Ethnicity, Condition, _Merged_caps_and_pss_within_30_days, _tei_total_types_experienced_somewitness, _childabphyssexemot_ctq_01modandsev, _CD4Tcells(%), _NKcells(%), _Bcells(%), _Monocytes(%), _Neutrophiles(%), Platform]
# Index: []
